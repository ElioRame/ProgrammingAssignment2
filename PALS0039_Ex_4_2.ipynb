# %% [markdown]
# <a href="https://colab.research.google.com/github/ElioRame/ProgrammingAssignment2/blob/master/PALS0039_Ex_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![PALS0039 Logo](https://www.phon.ucl.ac.uk/courses/pals0039/images/pals0039logo.png)](https://www.phon.ucl.ac.uk/courses/pals0039/)
#
# #Exercise 4.2 Age Prediction from speech
#
# In this exercise we implement a DNN for predicting age of the speaker from speech.
#
# The data comes from the [Accents of the British Isles](http://www.thespeechark.com/abi-2-page.html) corpus. Each speaker read the same short passage, and the audio was processed using the [OpenSMILE](https://www.audeering.com/opensmile/) toolkit into fixed-length vectors of 6373 features. We normalise the features across all speakers using z-scores. We add GENDER as an additional input feature. We convert the speaker AGE into a value between 0-1 and build a network with a linear output to predict age. We plot the predictions as a scatter plot, and calculate correlation and mean absolute error.

# %% [markdown]
# ---
# Set up the environment and load the pre-prepared data from the course website. Run the code.

# %%
# import standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# import keras libraries
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# load a CSV file and divide into feats and labels
def load_csv(filename, outcolname="AGE", featcolstart=4):
  # read CSV file
  df = pd.read_csv(filename, sep=',')
  # convert GENDER column to codes
  gender = pd.Categorical(df['GENDER'])
  # append gender code to audio features
  inputs = np.append(np.array(df.iloc[:, featcolstart:]), np.reshape(gender.codes, (len(df),1)), axis=1)
  # convert age to numpy array
  outputs = df[outcolname].to_numpy()
  # randomise order
  p = np.random.permutation(inputs.shape[0])
  return inputs[p], outputs[p]

# download train and test data
Xtrain, ytrain = load_csv("https://www.phon.ucl.ac.uk/courses/pals0039/data/exercise_04/age-train.csv.bz2");
Xtest, ytest = load_csv("https://www.phon.ucl.ac.uk/courses/pals0039/data/exercise_04/age-test.csv.bz2");

# Show counts for the datasets
print("Number of training samples (rows):", Xtrain.shape[0], len(ytrain), sep="\t")
print("Number of test samples (rows)    :", Xtest.shape[0], len(ytest), sep="\t")
print("Number of features (columns)     :", Xtrain.shape[1], Xtest.shape[1], sep="\t")
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Number of training samples (rows):	210	210
# Number of test samples (rows)    :	52	52
# Number of features (columns)     :	6374	6374

# %% [markdown]
# ---
# Normalise the features using [`sklearn`'s preprocessing tools](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing). Run the code.

# %%
# Get statistics of all features
scaler = StandardScaler().fit(Xtrain)

# Normalise the training and test features
Xtrain_norm = scaler.transform(Xtrain)
Xtest_norm = scaler.transform(Xtest)

# Convert ages to a small number
# Maximum ages in the data are in the 80s
# So outputs should lie well inside the range [0.0, 1.0]
ytrain_norm = ytrain / 100.0
ytest_norm = ytest / 100.0

# %% [markdown]
# ---
# (a) Build a model. Run the code and add comments. Why do we use the `tanh` activation function for the hidden layers? What is the [`Dropout` layer](https://keras.io/api/layers/regularization_layers/dropout/)?

# %%
def build_model(input_width, output_width=1):
  model = Sequential()
  model.add(Dense(64, activation='tanh', input_shape=(input_width,)))
  model.add(Dropout(0.5))
  model.add(Dense(32, activation='tanh'))
  model.add(Dense(output_width, activation='linear'))
  model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])
  return model

#(a)
model = build_model(Xtrain_norm.shape[1])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 64)             │       408,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410,113 (1.56 MB)
#  Trainable params: 410,113 (1.56 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ---
# (b) Call the `model.fit` method with the correct arguments to train the model with the following specifications: (1) Train for 100 iterations over the dataset; (2) Update the weights during training in batches of 32 samples; (3) Request Keras to randomly select 10% of the training set as the **validation set**.

# %%
training_info = model.fit(Xtrain_norm, ytrain_norm, epochs = 100, batch_size = 32, validation_split = 0.10)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - loss: 1.0716 - mae: 0.8161 - val_loss: 0.6703 - val_mae: 0.6780
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4513 - mae: 0.5219 - val_loss: 0.5437 - val_mae: 0.6160
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3956 - mae: 0.5083 - val_loss: 0.4109 - val_mae: 0.5221
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3761 - mae: 0.4941 - val_loss: 0.3619 - val_mae: 0.4656
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3165 - mae: 0.4563 - val_loss: 0.2871 - val_mae: 0.4143
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2977 - mae: 0.4419 - val_loss: 0.3094 - val_mae: 0.4434
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2760 - mae: 0.4267 - val_loss: 0.1570 - val_mae: 0.2956
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2372 - mae: 0.3936 - val_loss: 0.2120 - val_mae: 0.3426
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2315 - mae: 0.3934 - val_loss: 0.1910 - val_mae: 0.3388
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2090 - mae: 0.3825 - val_loss: 0.1752 - val_mae: 0.3255
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1622 - mae: 0.3153 - val_loss: 0.1820 - val_mae: 0.3439
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1941 - mae: 0.3517 - val_loss: 0.2061 - val_mae: 0.3730
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1563 - mae: 0.3172 - val_loss: 0.1815 - val_mae: 0.3358
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1700 - mae: 0.3243 - val_loss: 0.1448 - val_mae: 0.2934
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1432 - mae: 0.3042 - val_loss: 0.1305 - val_mae: 0.2871
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1264 - mae: 0.2820 - val_loss: 0.1109 - val_mae: 0.2625
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1610 - mae: 0.3305 - val_loss: 0.0920 - val_mae: 0.2409
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1795 - mae: 0.3501 - val_loss: 0.0920 - val_mae: 0.2549
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1318 - mae: 0.2956 - val_loss: 0.0803 - val_mae: 0.2342
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1261 - mae: 0.2800 - val_loss: 0.0659 - val_mae: 0.2009
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1275 - mae: 0.2937 - val_loss: 0.0736 - val_mae: 0.2149
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1321 - mae: 0.2952 - val_loss: 0.0789 - val_mae: 0.2431
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1233 - mae: 0.2757 - val_loss: 0.0675 - val_mae: 0.2214
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0973 - mae: 0.2448 - val_loss: 0.0855 - val_mae: 0.2406
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1056 - mae: 0.2607 - val_loss: 0.0675 - val_mae: 0.1950
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1065 - mae: 0.2616 - val_loss: 0.0468 - val_mae: 0.1826
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1127 - mae: 0.2751 - val_loss: 0.0592 - val_mae: 0.1918
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1120 - mae: 0.2718 - val_loss: 0.0651 - val_mae: 0.2135
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1061 - mae: 0.2584 - val_loss: 0.0467 - val_mae: 0.1822
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0880 - mae: 0.2383 - val_loss: 0.0579 - val_mae: 0.1941
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0964 - mae: 0.2487 - val_loss: 0.0609 - val_mae: 0.2137
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0953 - mae: 0.2450 - val_loss: 0.0978 - val_mae: 0.2527
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0873 - mae: 0.2331 - val_loss: 0.0854 - val_mae: 0.2421
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1028 - mae: 0.2544 - val_loss: 0.1006 - val_mae: 0.2722
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1102 - mae: 0.2569 - val_loss: 0.0872 - val_mae: 0.2567
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0925 - mae: 0.2474 - val_loss: 0.0789 - val_mae: 0.2527
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0908 - mae: 0.2399 - val_loss: 0.1097 - val_mae: 0.2881
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0971 - mae: 0.2468 - val_loss: 0.0920 - val_mae: 0.2625
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0961 - mae: 0.2524 - val_loss: 0.0895 - val_mae: 0.2649
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0958 - mae: 0.2493 - val_loss: 0.0653 - val_mae: 0.2220
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1172 - mae: 0.2727 - val_loss: 0.0668 - val_mae: 0.2312
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0766 - mae: 0.2226 - val_loss: 0.0868 - val_mae: 0.2629
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0993 - mae: 0.2494 - val_loss: 0.0810 - val_mae: 0.2500
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0693 - mae: 0.2136 - val_loss: 0.0591 - val_mae: 0.2118
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0611 - mae: 0.2007 - val_loss: 0.0538 - val_mae: 0.2019
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1037 - mae: 0.2566 - val_loss: 0.0516 - val_mae: 0.1912
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0880 - mae: 0.2395 - val_loss: 0.0561 - val_mae: 0.1892
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0908 - mae: 0.2475 - val_loss: 0.0481 - val_mae: 0.1841
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0803 - mae: 0.2269 - val_loss: 0.0521 - val_mae: 0.1881
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0712 - mae: 0.2092 - val_loss: 0.0594 - val_mae: 0.1981
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0717 - mae: 0.2122 - val_loss: 0.0563 - val_mae: 0.1970
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0701 - mae: 0.2042 - val_loss: 0.0661 - val_mae: 0.2106
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0613 - mae: 0.1948 - val_loss: 0.0613 - val_mae: 0.1887
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0686 - mae: 0.2124 - val_loss: 0.0591 - val_mae: 0.1841
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0725 - mae: 0.2168 - val_loss: 0.0506 - val_mae: 0.1778
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0606 - mae: 0.1918 - val_loss: 0.0510 - val_mae: 0.1818
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0546 - mae: 0.1775 - val_loss: 0.0603 - val_mae: 0.2082
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0539 - mae: 0.1832 - val_loss: 0.0600 - val_mae: 0.2053
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0822 - mae: 0.2269 - val_loss: 0.0598 - val_mae: 0.2103
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0542 - mae: 0.1815 - val_loss: 0.0427 - val_mae: 0.1721
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0607 - mae: 0.2024 - val_loss: 0.0667 - val_mae: 0.2103
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0664 - mae: 0.2154 - val_loss: 0.0654 - val_mae: 0.2050
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0414 - mae: 0.1609 - val_loss: 0.0600 - val_mae: 0.2047
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0527 - mae: 0.1792 - val_loss: 0.0653 - val_mae: 0.2067
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0552 - mae: 0.1901 - val_loss: 0.0600 - val_mae: 0.1942
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0500 - mae: 0.1740 - val_loss: 0.0660 - val_mae: 0.1932
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0618 - mae: 0.2034 - val_loss: 0.0538 - val_mae: 0.1937
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0498 - mae: 0.1818 - val_loss: 0.0602 - val_mae: 0.1944
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0466 - mae: 0.1718 - val_loss: 0.0592 - val_mae: 0.1897
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0533 - mae: 0.1815 - val_loss: 0.0550 - val_mae: 0.1836
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0454 - mae: 0.1785 - val_loss: 0.0437 - val_mae: 0.1723
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0518 - mae: 0.1841 - val_loss: 0.0540 - val_mae: 0.1894
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0434 - mae: 0.1616 - val_loss: 0.0555 - val_mae: 0.1859
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0397 - mae: 0.1627 - val_loss: 0.0596 - val_mae: 0.2016
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0422 - mae: 0.1669 - val_loss: 0.0566 - val_mae: 0.1939
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0555 - mae: 0.1911 - val_loss: 0.0555 - val_mae: 0.1926
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0558 - mae: 0.1888 - val_loss: 0.0549 - val_mae: 0.1973
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0467 - mae: 0.1748 - val_loss: 0.0491 - val_mae: 0.1939
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0527 - mae: 0.1847 - val_loss: 0.0533 - val_mae: 0.2016
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0392 - mae: 0.1578 - val_loss: 0.0483 - val_mae: 0.1882
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0478 - mae: 0.1713 - val_loss: 0.0555 - val_mae: 0.1977
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0334 - mae: 0.1432 - val_loss: 0.0465 - val_mae: 0.1820
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0402 - mae: 0.1560 - val_loss: 0.0550 - val_mae: 0.1830
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0424 - mae: 0.1626 - val_loss: 0.0565 - val_mae: 0.2029
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0423 - mae: 0.1653 - val_loss: 0.0541 - val_mae: 0.1937
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0383 - mae: 0.1538 - val_loss: 0.0511 - val_mae: 0.1856
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0384 - mae: 0.1512 - val_loss: 0.0455 - val_mae: 0.1637
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0408 - mae: 0.1636 - val_loss: 0.0487 - val_mae: 0.1769
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0341 - mae: 0.1469 - val_loss: 0.0502 - val_mae: 0.1712
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0358 - mae: 0.1418 - val_loss: 0.0474 - val_mae: 0.1720
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0341 - mae: 0.1483 - val_loss: 0.0459 - val_mae: 0.1682
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0398 - mae: 0.1501 - val_loss: 0.0473 - val_mae: 0.1615
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0376 - mae: 0.1531 - val_loss: 0.0475 - val_mae: 0.1744
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0314 - mae: 0.1471 - val_loss: 0.0429 - val_mae: 0.1530
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0344 - mae: 0.1427 - val_loss: 0.0410 - val_mae: 0.1560
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0331 - mae: 0.1442 - val_loss: 0.0413 - val_mae: 0.1681
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0403 - mae: 0.1669 - val_loss: 0.0475 - val_mae: 0.1821
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0278 - mae: 0.1333 - val_loss: 0.0441 - val_mae: 0.1733
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0320 - mae: 0.1446 - val_loss: 0.0434 - val_mae: 0.1724
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0290 - mae: 0.1355 - val_loss: 0.0487 - val_mae: 0.1809

# %%
def plot_training_history(training_info):
  # Plot the training process:
  fig, axs = plt.subplots(1, 2, figsize=(16, 5))
  axs[0].plot(training_info.history['loss'], label="training set")
  axs[0].plot(training_info.history['val_loss'], label="validation set")
  axs[0].set_xlabel("Epoch")
  axs[0].set_ylabel("Loss")
  axs[0].grid(True)
  axs[0].legend()
  try:
    axs[1].plot(training_info.history['mae'], label="training set")
    axs[1].plot(training_info.history['val_mae'], label="validation set")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Mean Absolute Error")
    axs[1].grid(True)
    axs[1].legend()
  except:
    pass
  plt.show()

plot_training_history(training_info)

# %% [markdown]
# (c) Does the process exhibit overfitting or underfitting? Is the performance of the classifier good? Is 100 epochs a reasonable choice? Should the number of epochs be increased or decreased? How could it be that the training error is larger than the validation error?

# %%
#(c)
#the model's performance is close to optimal, 100 is a reasonable choice. increasing epochs would lead to overfitting. good generalisation + The validation error could be lower because training error is calculated with dropout.

# %% [markdown]
# (d) Estimate the generalisation performance of the two models on the test set (use the [model.evaluate method](https://keras.io/api/models/model_training_apis/#evaluate-method). How does the test accuracy compare to those on the validation set?

# %%
#(d)
#ANSWER
test_loss, test_mae = model.evaluate(Xtest_norm, ytest_norm, verbose=0)
print("Test loss:", test_loss)
print("Test Mean Absolute Error (years):", test_mae * 100.0)
# Out:
# Test loss: 0.04286792501807213
# Test Mean Absolute Error (years): 15.595623850822449

# %% [markdown]
# ---
# Plot predictions vs. actual age, run the code.

# %%
# get predictions of model
ypred_norm = model.predict(Xtest_norm)

# convert back to years
ypred = ypred_norm.flatten() * 100.0

# calculate some statistics
rmse = np.sqrt(np.mean((ytest - ypred) * (ytest - ypred)))
mae = np.mean(np.abs(ytest - ypred))
corr = np.corrcoef(ytest, ypred);

# plot male and female in different colours
colours = ['red', 'blue']
cols = list(colours[int(i)] for i in Xtest[:,Xtest.shape[1] - 1])
# plot a scatter plot
plt.scatter(x=ytest, y=ypred, c=cols, s=20, alpha=0.5);
# calculate a line of best fit
poly = np.polyfit(ytest, ypred, 1)
x = np.array((np.min(ytest), np.max(ytest)))
y = poly[1] + poly[0] * x
plt.plot(x,y,':g')
plt.xlabel("Actual Age (yr)");
plt.ylabel("Predicted Age (yr)");
plt.grid()
plt.title("RMSE=%.3f MAE=%.3f r=%.3f" % (rmse, mae, corr[0, 1]));
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %% [markdown]
# ---
# (e) **Optional**: Experiment with the network to try and improve performance. Some ideas:
#
# - Remove the feature normalisation step - is it useful?
# - Change the structure of the network or training regime (advanced) Select a subset of the 6373 features depending on whether the feature has a useful correlation with speaker AGE. Remove features from the training and test sets which do not correlate with age to any useful degree.
# - What is the benefit of feature selection here, does it improve the accuracy of the model?
