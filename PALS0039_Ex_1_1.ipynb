# %% [markdown]
# <a href="https://colab.research.google.com/github/ElioRame/ProgrammingAssignment2/blob/master/PALS0039_Ex_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![PALS0039 Logo](https://www.phon.ucl.ac.uk/courses/pals0039/images/pals0039logo.png)](https://www.phon.ucl.ac.uk/courses/pals0039/)
#
# # Exercise 1.1 Python practice
#
# ## Statistics, functions and methods
#
# Recall the following code from a previous exercise:

# %%
# Use python modules:
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
# %matplotlib inline
#constructing data from scratch by choosing mean and sdev and creating continuous variables around mean and sdev for both female and male pitch distribution using ss.norm
#x_values creates an array starting at 75 and going to 260 with 0.001 increments
#ss.norm.pdf refers to the probability density function (relative likelihood of values in a continuous distribution)
#.pdf(x) refers to the derivative of x's cumulative distribution function (probability density of each point in the array and will add up to 1)
#the following are python OBJECTS
f_pitch_mean = 160.0
f_pitch_sdev = 15.0
m_pitch_mean = 120.0
m_pitch_sdev = 11.7

# Plot distributions
x_values = np.arange(start=75.0,
                     stop=260.0,
                     step=0.001)
f_pitch_distribution = ss.norm(f_pitch_mean,
                                f_pitch_sdev)
m_pitch_distribution = ss.norm(m_pitch_mean,
                                m_pitch_sdev)

plt.plot(x_values,
         f_pitch_distribution.pdf(x_values),
         label="Female pitch distribution")
plt.plot(x_values,
         m_pitch_distribution.pdf(x_values),
         label="Male pitch distribution")
plt.legend()

# %% [markdown]
# The two normal distributions describe the typical pitch values found in the speech of female and male speakers and are represented by the *Python objects* **`f_pitch_distribution`** and **`m_pitch_distribution`**. These objects have *methods* that may be used to query the distributions, for example, the *probability density function* (`pdf` method) is used in the above plots (see [this reference](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html) for more information).
#
# (a) Using these distributions, write a Python function that would *classify* a pitch value from a new utterance as being spoken by either a female or male speaker **based on which is most likely**.
#
# (b) Apply the function to the two sets of measurements taken for male and female speakers (defined in `pitch_male_utterances` and `pitch_female_utterances`) and print out the results.
#
# (c) Does the classifier perform perfectly on the test measurements? Why?

# %%
f_pitch_measurements = [173.035,
                        151.889,
                        172.420,
                        177.477,
                        201.272,
                        147.098,
                        149.223,
                        150.374,
                        134.374,
                        171.970]

print(sum(f_pitch_measurements)/10)
m_pitch_measurements = [150.637,
                        137.966,
                        140.504,
                         96.626,
                        131.268,
                        124.797,
                        142.892,
                        123.493,
                        117.713,
                        130.044]

#(a)
def classify_utterance_speaker(pitch_value):

   if sum(pitch_value)/len(pitch_value) < 150:
    print("The speaker is male.")
   else:
    print("The speaker is female.")

#(b)
classify_utterance_speaker(f_pitch_measurements)
print("--------------------------------------")
print("RESULTS FOR FEMALE PITCH MEASUREMENTS:")
#ANSWER
classify_utterance_speaker(m_pitch_measurements)
print("--------------------------------------")
print("RESULTS FOR MALE PITCH MEASUREMENTS:")
#ANSWER
print("--------------------------------------")

#(c)
#it performs according to the instrructions given (in this case, mean pitch value across utterances) - the reasoning behind this coding cannot be considered valid under further scrutiny as it is prone to being inaccurate when outliers are present
#and does not take into account anything else (i.e. males with high voices and females with low voices exist, and this function will not be able to classify children).
#ANSWER
# Out:
# 162.9132
# The speaker is female.
# --------------------------------------
# RESULTS FOR FEMALE PITCH MEASUREMENTS:
# The speaker is male.
# --------------------------------------
# RESULTS FOR MALE PITCH MEASUREMENTS:
# --------------------------------------

# %% [markdown]
# ## Text manipulation
#
# Given the text string assigned to the Python variable `two_cities`, do the following:
#
# (d) Write a function or code to split the text into a list of words, removing all punctuation in the process.
#
# Hint: Python's [`string`](https://docs.python.org/3/library/string.html) module contains useful methods and definitions.
#
# (e) Count the total number of words and unique words used.
#
# (f) Count the number of occurrences of each word and print the results in descending order by frequency of occurrence.
#
# Hints:
# - You could use a Python dictionary to keep track of the word counts.
# - You may find useful tools in Python's [`collections`](https://docs.python.org/3/library/collections.html) module.
# - Python's [sorting documentation](https://docs.python.org/3/howto/sorting.html)
#
# (g) Would your code work regardless of the input language? Why? How would you write a language-independent version?

# %%
import string
import collections
import operator

#From: https://www.gutenberg.org/files/98/98-h/98-h.htm
two_cities = """
It was the best of times, it was the worst of times,
it was the age of wisdom, it was the age of foolishness,
it was the epoch of belief, it was the epoch of incredulity,
it was the season of Light, it was the season of Darkness,
it was the spring of hope, it was the winter of despair,
we had everything before us, we had nothing before us,
we were all going direct to Heaven, we were all going direct the other way,
in short, the period was so far like the present period,
that some of its noisiest authorities insisted on its being received,
for good or for evil, in the superlative degree of comparison only.
"""

#(d)
#ANSWER

two_cities = two_cities.translate(str.maketrans("", "", string.punctuation)).split()
#the translate method makes use of the maketrans method (which facilitates mapping of characters/integers to characters/integers/none) to modify strings
#the first and second args (mapping arg 1 to arg 2) are not used here because our goal is to remove characters (punctuation, a list of which is handily included in string.puctuation)
#arg 3 maps each character in a string to None
print(two_cities)

print(two_cities, len(two_cities))
count = {}
unique = {}
for word in two_cities:
  if word not in count:
    count[word] = 1
  else:
    count[word] += 1
  if word not in unique:
    unique[word] = 1
  else:
    continue
print(dict(sorted(count.items(), key = lambda item : item[1])), len(count))
print(unique, len(unique))
#the function above takes the items in a dictionary and sorts them based on the key established element (here being element 1, i.e. the second element, the number in this case)
np.arange

#(e)
#ANSWER

#(f)
#ANSWER

#(g)
#ANSWER
# Out:
# ['It', 'was', 'the', 'best', 'of', 'times', 'it', 'was', 'the', 'worst', 'of', 'times', 'it', 'was', 'the', 'age', 'of', 'wisdom', 'it', 'was', 'the', 'age', 'of', 'foolishness', 'it', 'was', 'the', 'epoch', 'of', 'belief', 'it', 'was', 'the', 'epoch', 'of', 'incredulity', 'it', 'was', 'the', 'season', 'of', 'Light', 'it', 'was', 'the', 'season', 'of', 'Darkness', 'it', 'was', 'the', 'spring', 'of', 'hope', 'it', 'was', 'the', 'winter', 'of', 'despair', 'we', 'had', 'everything', 'before', 'us', 'we', 'had', 'nothing', 'before', 'us', 'we', 'were', 'all', 'going', 'direct', 'to', 'Heaven', 'we', 'were', 'all', 'going', 'direct', 'the', 'other', 'way', 'in', 'short', 'the', 'period', 'was', 'so', 'far', 'like', 'the', 'present', 'period', 'that', 'some', 'of', 'its', 'noisiest', 'authorities', 'insisted', 'on', 'its', 'being', 'received', 'for', 'good', 'or', 'for', 'evil', 'in', 'the', 'superlative', 'degree', 'of', 'comparison', 'only']
# ['It', 'was', 'the', 'best', 'of', 'times', 'it', 'was', 'the', 'worst', 'of', 'times', 'it', 'was', 'the', 'age', 'of', 'wisdom', 'it', 'was', 'the', 'age', 'of', 'foolishness', 'it', 'was', 'the', 'epoch', 'of', 'belief', 'it', 'was', 'the', 'epoch', 'of', 'incredulity', 'it', 'was', 'the', 'season', 'of', 'Light', 'it', 'was', 'the', 'season', 'of', 'Darkness', 'it', 'was', 'the', 'spring', 'of', 'hope', 'it', 'was', 'the', 'winter', 'of', 'despair', 'we', 'had', 'everything', 'before', 'us', 'we', 'had', 'nothing', 'before', 'us', 'we', 'were', 'all', 'going', 'direct', 'to', 'Heaven', 'we', 'were', 'all', 'going', 'direct', 'the', 'other', 'way', 'in', 'short', 'the', 'period', 'was', 'so', 'far', 'like', 'the', 'present', 'period', 'that', 'some', 'of', 'its', 'noisiest', 'authorities', 'insisted', 'on', 'its', 'being', 'received', 'for', 'good', 'or', 'for', 'evil', 'in', 'the', 'superlative', 'degree', 'of', 'comparison', 'only'] 119
# {'It': 1, 'best': 1, 'worst': 1, 'wisdom': 1, 'foolishness': 1, 'belief': 1, 'incredulity': 1, 'Light': 1, 'Darkness': 1, 'spring': 1, 'hope': 1, 'winter': 1, 'despair': 1, 'everything': 1, 'nothing': 1, 'to': 1, 'Heaven': 1, 'other': 1, 'way': 1, 'short': 1, 'so': 1, 'far': 1, 'like': 1, 'present': 1, 'that': 1, 'some': 1, 'noisiest': 1, 'authorities': 1, 'insisted': 1, 'on': 1, 'being': 1, 'received': 1, 'good': 1, 'or': 1, 'evil': 1, 'superlative': 1, 'degree': 1, 'comparison': 1, 'only': 1, 'times': 2, 'age': 2, 'epoch': 2, 'season': 2, 'had': 2, 'before': 2, 'us': 2, 'were': 2, 'all': 2, 'going': 2, 'direct': 2, 'in': 2, 'period': 2, 'its': 2, 'for': 2, 'we': 4, 'it': 9, 'was': 11, 'of': 12, 'the': 14} 59
# {'It': 1, 'was': 1, 'the': 1, 'best': 1, 'of': 1, 'times': 1, 'it': 1, 'worst': 1, 'age': 1, 'wisdom': 1, 'foolishness': 1, 'epoch': 1, 'belief': 1, 'incredulity': 1, 'season': 1, 'Light': 1, 'Darkness': 1, 'spring': 1, 'hope': 1, 'winter': 1, 'despair': 1, 'we': 1, 'had': 1, 'everything': 1, 'before': 1, 'us': 1, 'nothing': 1, 'were': 1, 'all': 1, 'going': 1, 'direct': 1, 'to': 1, 'Heaven': 1, 'other': 1, 'way': 1, 'in': 1, 'short': 1, 'period': 1, 'so': 1, 'far': 1, 'like': 1, 'present': 1, 'that': 1, 'some': 1, 'its': 1, 'noisiest': 1, 'authorities': 1, 'insisted': 1, 'on': 1, 'being': 1, 'received': 1, 'for': 1, 'good': 1, 'or': 1, 'evil': 1, 'superlative': 1, 'degree': 1, 'comparison': 1, 'only': 1} 59
# <function numpy.arange>
